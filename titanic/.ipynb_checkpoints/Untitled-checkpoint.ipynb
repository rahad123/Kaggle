# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sbn

# %%
train_data = pd.read_csv('train.csv')
train_data

y = train_data.Survived
y
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
age_mean = train_data['Age'].fillna(train_data.Age.mean())
train_data.Age = age_mean
train_data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
train_data.describe
# Out:
# <bound method NDFrame.describe of      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ...

# %%
train_data.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex        Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.000000      0      0      211536  13.00   NaN        S
# 887  female  19.000000      0      0      112053  30.00   B42        S
# 888  female  29.699118      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.000000      0      0      111369  30.00  C148        C
# 890    male  32.000000      0      0      370376   7.75   NaN        Q

# %%
numeric_variables = list(train_data.dtypes[train_data.dtypes != "object"].index)
train = train_data[numeric_variables]

# %%
train
# Out:
#      PassengerId  Survived  Pclass        Age  SibSp  Parch     Fare
# 0              1         0       3  22.000000      1      0   7.2500
# 1              2         1       1  38.000000      1      0  71.2833
# 2              3         1       3  26.000000      0      0   7.9250
# 3              4         1       1  35.000000      1      0  53.1000
# 4              5         0       3  35.000000      0      0   8.0500
# ..           ...       ...     ...        ...    ...    ...      ...
# 886          887         0       2  27.000000      0      0  13.0000
# 887          888         1       1  19.000000      0      0  30.0000
# 888          889         0       3  29.699118      1      2  23.4500
# 889          890         1       1  26.000000      0      0  30.0000
# 890          891         0       3  32.000000      0      0   7.7500
#
# [891 rows x 7 columns]

# %%
test_data = pd.read_csv('test.csv')
test_data.head(10)

test_mean = test_data['Age'].fillna(test_data.Age.mean())
test_data.Age = test_mean
test_data

numeric_values = list(test_data.dtypes[test_data.dtypes != "object"].index)
test = test_data[numeric_values]
test
# Out:
#      PassengerId  Pclass       Age  SibSp  Parch      Fare
# 0            892       3  34.50000      0      0    7.8292
# 1            893       3  47.00000      1      0    7.0000
# 2            894       2  62.00000      0      0    9.6875
# 3            895       3  27.00000      0      0    8.6625
# 4            896       3  22.00000      1      1   12.2875
# ..           ...     ...       ...    ...    ...       ...
# 413         1305       3  30.27259      0      0    8.0500
# 414         1306       1  39.00000      0      0  108.9000
# 415         1307       3  38.50000      0      0    7.2500
# 416         1308       3  30.27259      0      0    8.0500
# 417         1309       3  30.27259      1      1   22.3583
#
# [418 rows x 6 columns]

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier()
model.fit(train, y)

# %%
data_te
